# %% [markdown]
# Tugas Praktikum

# %% [markdown]
# Langkah:
#
# 1. Load dataset MNIST dari Keras.
# 2. Bangun model dengan 2 hidden layer.
# 3. Latih model dan evaluasi akurasi.

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

# 1. Load dataset MNIST
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Normalisasi data (0-255 → 0-1)
X_train = X_train / 255.0
X_test = X_test / 255.0

# One-hot encoding label
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# 2. Bangun model JST
model = Sequential([
    # Ubah gambar 28x28 menjadi vektor
    Flatten(input_shape=(28, 28)),
    # Hidden layer 1
    Dense(128, activation='relu'),
    # Hidden layer 2
    Dense(64, activation='relu'),
    # Output layer (10 kelas)
    Dense(10, activation='softmax')
])

# 3. Kompilasi model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# 4. Latih model
# kecilkan epochs jika ingin eksekusi cepat; ubah sesuai kebutuhan
model.fit(X_train, y_train, epochs=5, batch_size=32, validation_split=0.1, verbose=2)

# 5. Evaluasi model
loss, acc = model.evaluate(X_test, y_test, verbose=2)
print(f"Akurasi pada data uji: {acc:.4f}")
# Out:
# c:\Users\ASUS\anaconda3\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 1688/1688 - 6s - 3ms/step - accuracy: 0.9252 - loss: 0.2530 - val_accuracy: 0.9643 - val_loss: 0.1170
# Epoch 2/5
# 1688/1688 - 5s - 3ms/step - accuracy: 0.9683 - loss: 0.1068 - val_accuracy: 0.9763 - val_loss: 0.0837
# Epoch 3/5
# 1688/1688 - 4s - 2ms/step - accuracy: 0.9771 - loss: 0.0732 - val_accuracy: 0.9757 - val_loss: 0.0859
# Epoch 4/5
# 1688/1688 - 5s - 3ms/step - accuracy: 0.9822 - loss: 0.0548 - val_accuracy: 0.9707 - val_loss: 0.1047
# Epoch 5/5
# 1688/1688 - 3s - 2ms/step - accuracy: 0.9853 - loss: 0.0445 - val_accuracy: 0.9775 - val_loss: 0.0790
# 313/313 - 1s - 2ms/step - accuracy: 0.9755 - loss: 0.0845
# Akurasi pada data uji: 0.9755

# %% [markdown]
# Coba dengan beberapa parameter lain:

# %% [markdown]
# Ubah jumlah neuron di hidden layer (misal: 256 dan 128).

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

# Load data
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train, X_test = X_train/255.0, X_test/255.0
y_train, y_test = to_categorical(y_train, 10), to_categorical(y_test, 10)

# Model dengan neuron lebih banyak
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(256, activation='relu'),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=5, batch_size=32,
          validation_split=0.1, verbose=2)

loss, acc = model.evaluate(X_test, y_test, verbose=0)
print("Akurasi:", acc)
print("Loss:", loss)
# Out:
# Epoch 1/5
# 1688/1688 - 6s - 4ms/step - accuracy: 0.9338 - loss: 0.2184 - val_accuracy: 0.9737 - val_loss: 0.0972
# Epoch 2/5
# 1688/1688 - 5s - 3ms/step - accuracy: 0.9731 - loss: 0.0886 - val_accuracy: 0.9750 - val_loss: 0.0811
# Epoch 3/5
# 1688/1688 - 5s - 3ms/step - accuracy: 0.9799 - loss: 0.0618 - val_accuracy: 0.9775 - val_loss: 0.0788
# Epoch 4/5
# 1688/1688 - 5s - 3ms/step - accuracy: 0.9850 - loss: 0.0472 - val_accuracy: 0.9767 - val_loss: 0.0806
# Epoch 5/5
# 1688/1688 - 5s - 3ms/step - accuracy: 0.9884 - loss: 0.0350 - val_accuracy: 0.9770 - val_loss: 0.0784
# Akurasi: 0.9750000238418579
# Loss: 0.08865205198526382

# %% [markdown]
# Tambahkan satu hidden layer lagi.

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

# Load data
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train, X_test = X_train/255.0, X_test/255.0
y_train, y_test = to_categorical(y_train, 10), to_categorical(y_test, 10)

# Model dengan 3 hidden layer
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=5, batch_size=32,
          validation_split=0.1, verbose=2)

loss, acc = model.evaluate(X_test, y_test, verbose=0)
print("Akurasi:", acc)
print("Loss:", loss)
# Out:
# Epoch 1/5
# 1688/1688 - 5s - 3ms/step - accuracy: 0.9219 - loss: 0.2619 - val_accuracy: 0.9548 - val_loss: 0.1473
# Epoch 2/5
# 1688/1688 - 4s - 2ms/step - accuracy: 0.9673 - loss: 0.1088 - val_accuracy: 0.9700 - val_loss: 0.0962
# Epoch 3/5
# 1688/1688 - 4s - 2ms/step - accuracy: 0.9762 - loss: 0.0768 - val_accuracy: 0.9765 - val_loss: 0.0803
# Epoch 4/5
# 1688/1688 - 4s - 2ms/step - accuracy: 0.9810 - loss: 0.0586 - val_accuracy: 0.9762 - val_loss: 0.0833
# Epoch 5/5
# 1688/1688 - 4s - 2ms/step - accuracy: 0.9849 - loss: 0.0471 - val_accuracy: 0.9797 - val_loss: 0.0756
# Akurasi: 0.9775999784469604
# Loss: 0.07640302926301956

# %% [markdown]
# Bandingkan akurasi dan waktu pelatihan.

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

# Load data
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train, X_test = X_train/255.0, X_test/255.0
y_train, y_test = to_categorical(y_train, 10), to_categorical(y_test, 10)

# Model dengan aktivasi Sigmoid
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='sigmoid'),
    Dense(64, activation='sigmoid'),
    Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=5, batch_size=32,
          validation_split=0.1, verbose=2)

loss, acc = model.evaluate(X_test, y_test, verbose=0)
print("Akurasi:", acc)
print("Loss:", loss)
# Out:
# Epoch 1/5
# 1688/1688 - 5s - 3ms/step - accuracy: 0.8743 - loss: 0.4955 - val_accuracy: 0.9493 - val_loss: 0.1819
# Epoch 2/5
# 1688/1688 - 4s - 2ms/step - accuracy: 0.9434 - loss: 0.1909 - val_accuracy: 0.9627 - val_loss: 0.1328
# Epoch 3/5
# 1688/1688 - 3s - 2ms/step - accuracy: 0.9598 - loss: 0.1335 - val_accuracy: 0.9702 - val_loss: 0.1052
# Epoch 4/5
# 1688/1688 - 4s - 2ms/step - accuracy: 0.9703 - loss: 0.0995 - val_accuracy: 0.9733 - val_loss: 0.0974
# Epoch 5/5
# 1688/1688 - 4s - 2ms/step - accuracy: 0.9772 - loss: 0.0780 - val_accuracy: 0.9750 - val_loss: 0.0870
# Akurasi: 0.9700999855995178
# Loss: 0.0961821973323822

# %% [markdown]
# Eksperimen dengan fungsi aktivasi Sigmoid vs ReLU.

# %% [markdown]
# Model ReLU

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

# Load dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Normalisasi
X_train = X_train / 255.0
X_test = X_test / 255.0

# One-hot
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Model aktivasi ReLU
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=5, batch_size=32,
          validation_split=0.1, verbose=2)

loss, acc = model.evaluate(X_test, y_test, verbose=0)
print("=== ReLU Model ===")
print("Akurasi:", acc)
print("Loss:", loss)
# Out:
# Epoch 1/5
# 1688/1688 - 6s - 3ms/step - accuracy: 0.9250 - loss: 0.2573 - val_accuracy: 0.9657 - val_loss: 0.1178
# Epoch 2/5
# 1688/1688 - 6s - 3ms/step - accuracy: 0.9676 - loss: 0.1069 - val_accuracy: 0.9713 - val_loss: 0.0977
# Epoch 3/5
# 1688/1688 - 5s - 3ms/step - accuracy: 0.9768 - loss: 0.0750 - val_accuracy: 0.9722 - val_loss: 0.1005
# Epoch 4/5
# 1688/1688 - 5s - 3ms/step - accuracy: 0.9814 - loss: 0.0585 - val_accuracy: 0.9727 - val_loss: 0.0980
# Epoch 5/5
# 1688/1688 - 5s - 3ms/step - accuracy: 0.9859 - loss: 0.0431 - val_accuracy: 0.9757 - val_loss: 0.0830
# === ReLU Model ===
# Akurasi: 0.9742000102996826
# Loss: 0.08860316127538681

# %% [markdown]
# Model Sigmoid

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.utils import to_categorical

# Load dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Normalisasi
X_train = X_train / 255.0
X_test = X_test / 255.0

# One-hot
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Model aktivasi Sigmoid
model = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(128, activation='sigmoid'),
    Dense(64, activation='sigmoid'),
    Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=5, batch_size=32,
          validation_split=0.1, verbose=2)

loss, acc = model.evaluate(X_test, y_test, verbose=0)
print("=== Sigmoid Model ===")
print("Akurasi:", acc)
print("Loss:", loss)
# Out:
# Epoch 1/5
# 1688/1688 - 5s - 3ms/step - accuracy: 0.8717 - loss: 0.4944 - val_accuracy: 0.9493 - val_loss: 0.1859
# Epoch 2/5
# 1688/1688 - 4s - 2ms/step - accuracy: 0.9433 - loss: 0.1918 - val_accuracy: 0.9668 - val_loss: 0.1257
# Epoch 3/5
# 1688/1688 - 4s - 2ms/step - accuracy: 0.9606 - loss: 0.1333 - val_accuracy: 0.9688 - val_loss: 0.1067
# Epoch 4/5
# 1688/1688 - 5s - 3ms/step - accuracy: 0.9704 - loss: 0.0985 - val_accuracy: 0.9737 - val_loss: 0.0907
# Epoch 5/5
# 1688/1688 - 4s - 2ms/step - accuracy: 0.9774 - loss: 0.0761 - val_accuracy: 0.9762 - val_loss: 0.0808
# === Sigmoid Model ===
# Akurasi: 0.9742000102996826
# Loss: 0.08544082194566727
