# %% [markdown]
# Praktikum 3

# %% [markdown]
# Praktikum 3 kali ini kita akan mencoba menggunakan Keras untuk Regresi, khususnya pada kasus Prediksi Harga Rumah.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

# Contoh dataset (buat dummy data)
data = pd.DataFrame({
    'luas': [50, 60, 70, 80, 90],
    'harga': [500, 600, 700, 800, 900]
})

X = data[['luas']]
y = data[['harga']]

# Normalisasi
scaler = StandardScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation='relu', input_shape=(1,)),
    tf.keras.layers.Dense(1)
])

model.compile(optimizer='adam', loss='mse')
model.fit(X_train, y_train, epochs=100)

# Evaluasi
print("Prediksi:", model.predict(X_test))
# Out:
# Epoch 1/100
# c:\Users\ASUS\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 956ms/step - loss: 1.1004
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 1.0893
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 1.0782
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 1.0671
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 1.0561
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 1.0452
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 1.0344
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 1.0236
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 1.0128
# Epoch 10/100
# ...

# %% [markdown]
# Tugas 4:

# %% [markdown]
# Ubah learning rate.

# %% [markdown]
# Model Awal

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

# Dummy dataset
data = pd.DataFrame({
    'luas': [50, 60, 70, 80, 90],
    'harga': [500, 600, 700, 800, 900]
})

X = data[['luas']]
y = data[['harga']]

# Normalisasi
scaler_x = StandardScaler()
scaler_y = StandardScaler()
X = scaler_x.fit_transform(X)
y = scaler_y.fit_transform(y)

# Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Model awal
model_default = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation='relu', input_shape=(1,)),
    tf.keras.layers.Dense(1)
])

model_default.compile(optimizer='adam', loss='mse')

print("\n=== Training Model Default ===")
history_default = model_default.fit(X_train, y_train, epochs=100, verbose=0)

loss_default = model_default.evaluate(X_test, y_test)
print("Loss Default:", loss_default)
# Out:
# c:\Users\ASUS\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# === Training Model Default ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.2890
# Loss Default: 0.2889866232872009

# %% [markdown]
# Learning Rate Kecil

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

# Dummy dataset
data = pd.DataFrame({
    'luas': [50, 60, 70, 80, 90],
    'harga': [500, 600, 700, 800, 900]
})

X = data[['luas']]
y = data[['harga']]

# Normalisasi
scaler_x = StandardScaler()
scaler_y = StandardScaler()
X = scaler_x.fit_transform(X)
y = scaler_y.fit_transform(y)

# Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Model lr kecil
model_small_lr = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation='relu', input_shape=(1,)),
    tf.keras.layers.Dense(1)
])

optimizer_small = tf.keras.optimizers.Adam(learning_rate=0.001)

model_small_lr.compile(optimizer=optimizer_small, loss='mse')

print("\n=== Training Model LR 0.001 ===")
history_small = model_small_lr.fit(X_train, y_train, epochs=100, verbose=0)

loss_small_lr = model_small_lr.evaluate(X_test, y_test)
print("Loss LR 0.001:", loss_small_lr)
# Out:
# c:\Users\ASUS\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# === Training Model LR 0.001 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.4801
# Loss LR 0.001: 0.4800567328929901

# %% [markdown]
# Learning Rate Besar

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

# Dummy dataset
data = pd.DataFrame({
    'luas': [50, 60, 70, 80, 90],
    'harga': [500, 600, 700, 800, 900]
})

X = data[['luas']]
y = data[['harga']]

# Normalisasi
scaler_x = StandardScaler()
scaler_y = StandardScaler()
X = scaler_x.fit_transform(X)
y = scaler_y.fit_transform(y)

# Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Model lr besar
model_big_lr = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation='relu', input_shape=(1,)),
    tf.keras.layers.Dense(1)
])

optimizer_big = tf.keras.optimizers.Adam(learning_rate=0.1)

model_big_lr.compile(optimizer=optimizer_big, loss='mse')

print("\n=== Training Model LR 0.1 ===")
history_big = model_big_lr.fit(X_train, y_train, epochs=100, verbose=0)

loss_big_lr = model_big_lr.evaluate(X_test, y_test)
print("Loss LR 0.1:", loss_big_lr)
# Out:
# c:\Users\ASUS\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# === Training Model LR 0.1 ===
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 1.2910e-04
# Loss LR 0.1: 0.0001290954096475616

# %% [markdown]
# 2. Bandingkan hasil loss.

# %%
print("     PERBANDINGAN LOSS")
print("===========================")
print(f"Default LR (Adam): {loss_default:.6f}")
print(f"LR 0.001         : {loss_small_lr:.6f}")
print(f"LR 0.1           : {loss_big_lr:.6f}")

print("\nKeterangan:")
print("• LR kecil (0.001) : training lebih stabil tapi lebih lambat.")
print("• LR besar (0.1)   : cepat belajar tetapi bisa tidak stabil / loss besar.")
print("• Default Adam : biasanya paling seimbang.")
# Out:
#      PERBANDINGAN LOSS
# ...
# Default LR (Adam): 0.288987
# LR 0.001         : 0.480057
# LR 0.1           : 0.000129
#
# Keterangan:
# • LR kecil (0.001) : training lebih stabil tapi lebih lambat.
# • LR besar (0.1)   : cepat belajar tetapi bisa tidak stabil / loss besar.
# • Default Adam : biasanya paling seimbang.

# %% [markdown]
# Praktikum berikut akan menggunakan data Boston untuk memprediksi harga rumah.

# %%
# MLP regresi (Keras)
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# 1. Load (use California housing as replacement for deprecated Boston dataset)
data = fetch_california_housing()
X = data.data; y = data.target

# 2. Preprocess
scaler = StandardScaler(); Xs = scaler.fit_transform(X)
X_train, X_val, y_train, y_val = train_test_split(Xs, y, test_size=0.2, random_state=42)

# 3. Build model
model = Sequential([
Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
Dense(32, activation='relu'),
Dense(1)
])
model.compile(optimizer=Adam(1e-3), loss='mse', metrics=['mae'])

# 4. Train
h = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=200, batch_size=32, verbose=0)

# 5. Plot
plt.figure(figsize=(10,4))
plt.subplot(1,2,1); plt.plot(h.history['loss'], label='train_loss'); plt.plot(h.history['val_loss'], label='val_loss'); plt.legend(); plt.title('MSE')
plt.subplot(1,2,2); plt.plot(h.history['mae'], label='train_mae'); plt.plot(h.history['val_mae'], label='val_mae'); plt.legend(); plt.title('MAE')
plt.show()

from sklearn.metrics import mean_squared_error
pred = model.predict(X_val)
print('RMSE:', np.sqrt(mean_squared_error(y_val, pred)))
# Out:
# c:\Users\ASUS\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# RMSE: 0.5116044381288188
